# %%
import matplotlib.pyplot as plt
import numpy as np
 
K = np.array([0.01995016604, 0.0398013234, 0.05955444998, 0.07921050918, 0.09877045036, 0.118235209, 0.1376057069, 0.1538828526, 0.1760675417, 0.1951606567])
T = np.array([ 0.003365303719, 0.00332060435, 0.003277076847, 0.003234675724, 0.003193357816, 0.003153082138,0.003113809746, 0.00307503614,0.003038128513, 0.003001650908])


plt.plot(T, K, 'b')
 
plt.xlabel('1/T *1000')

plt.ylabel('ln K')

plt.title('')
plt.xlim(0.00299, 0.00339)
 
plt.show()

# %%
# V = np.array([0.5,1.5,2,2.5,3.05,3.5,4,4.5,5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,9.70,9.75,9.89,10,10.12,10.30,10.50,11,11.5,12.05,12.5,13,13.5,14,14.5,15.05,15.50,16,16.5,17,17.54,18,18.5,19,19.5,20,20.25,20.50])
# U = np.array([-5,0,3,6,8,10,12,14,16,19,22,26,29,33,38,44,52,61,79,84,95,106,136,301,328,340,352,364,373,377,381,388,391,394,395,400,405,416,413,419,425,433,445,466,596,618,630])


# # dUdV = np.diff(U) / np.diff(V)

# # plt.plot(dUdV, V)

# from matplotlib import pyplot as plt


# fig = plt.figure()
# ax = fig.add_subplot(111)



# ax.plot(V,dudv)
# for xy in zip(V, dudv):                                       # <--
#     ax.annotate('(%s, %s)' % xy, xy=xy, textcoords='data') # <--

# plt.xlabel('V in mL')

# plt.ylabel('dU/dV')

 
# plt.title('Potentiometrie')



# dudv = np.array([10.      ,      3.    ,        6.   ,         4.     ,       3.63636364,4.44444444  ,  4.   ,         4.   ,         6.   ,         6.,8.       ,     6.   ,         8. ,          10.   ,        12., 16.       ,   18.    ,       36.   ,        25.  ,        220.,78.57142857 ,272.72727273 ,1375.  ,        150.,           60.,24.    ,      24.   ,        16.36363636 ,   8.88888889 ,   8.,14.   ,         6.  ,          6.   ,         1.81818182,   11.11111111,10.  ,         22.   ,        -6.  ,         11.11111111 ,  13.04347826,16.    ,       24.    ,       42. ,         260.   ,        88.,48.     ])


# plt.plot(V,dudv)

# %%
# V = np.array([0.5,1.5,2,2.5,3.05,3.5,4,4.5,5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,9.70,9.75,9.89,10,10.12,10.30,10.50,11,11.5,12.05,12.5,13,13.5,14,14.5,15.05,15.50,16,16.5,17,17.54,18,18.5,19,19.5,20,20.25,20.50])
# U = np.array([-5,0,3,6,8,10,12,14,16,19,22,26,29,33,38,44,52,61,79,84,95,106,136,301,328,340,352,364,373,377,381,388,391,394,395,400,405,416,413,419,425,433,445,466,596,618,630])


# # dUdV = np.diff(U) / np.diff(V)

# # plt.plot(dUdV, V)

# from matplotlib import pyplot as plt


# fig = plt.figure()
# ax = fig.add_subplot(111)



# ax.plot(V,dudv)
# for xy in zip(V, dudv):                                       # <--
#     ax.annotate('(%s, %s)' % xy, xy=xy, textcoords='data') # <--

# plt.xlabel('V in mL')

# plt.ylabel('dU/dV')

 
# plt.title('Potentiometrie')



# dudv = np.array([10.      ,      3.    ,        6.   ,         4.     ,       3.63636364,4.44444444  ,  4.   ,         4.   ,         6.   ,         6.,8.       ,     6.   ,         8. ,          10.   ,        12., 16.       ,   18.    ,       36.   ,        25.  ,        220.,78.57142857 ,272.72727273 ,1375.  ,        150.,           60.,24.    ,      24.   ,        16.36363636 ,   8.88888889 ,   8.,14.   ,         6.  ,          6.   ,         1.81818182,   11.11111111,10.  ,         22.   ,        -6.  ,         11.11111111 ,  13.04347826,16.    ,       24.    ,       42. ,         260.   ,        88.,48.     ])


# plt.plot(V,dudv)

# %%
import matplotlib.pyplot as plt
import numpy as np



V = np.array([ 1,1.5,2,2.5,3,3.5,4,4.55,5,5.5,6,6.65,7,7.5,8,8.5,9,9.27,9.47,9.60,9.65,9.70,9.80,9.90,9.95,10,10.05,10.075,10.15,10.20,10.30,10.50,11,11.5,12.,12.5,13,13.5,14.05,14.5,15.,15.55,16,16.5,17.02,17.5,18,18.5,19.04,19.5,19.55,19.575,19.60,19.73,19.80,19.825,19.85,19.90,20])
U = np.array([2,5,6,8,10,12,14,17,19,22,24,27,31,35,39,45,53,63,69,77,84,88,91,99,112,119,136,168,236,288,334,347,356,364,368,372,377,380,385,387,392,393,396,401,406,410,421,426,433,448,472,474,478,482,504,547,569,583,592,609])

# # dUdV = np.diff(U) / np.diff(V)



from matplotlib import pyplot as plt
import numpy as np


# fig = plt.figure()
# ax = fig.add_subplot(111)



# ax.plot(V,dudv)
# for xy in zip(V, dudv):                                       # <--
#     ax.annotate('(%s, %s)' % xy, xy=xy, textcoords='data') # <--

plt.xlabel('V in mL')

plt.ylabel('dU/dV')

 
plt.title('1. Vorgang')



dudv = np.array([3.00000000e+00, 2.00000000e+00, 4.00000000e+00,4.00000000e+00,4.00000000e+00, 4.00000000e+00, 6.00000000e+00 ,3.63636364e+00,6.66666667e+00 ,4.00000000e+00, 6.00000000e+00, 6.15384615e+00,1.14285714e+01, 8.00000000e+00, 1.20000000e+01 ,1.60000000e+01,2.00000000e+01, 2.22222222e+01, 4.00000000e+01, 5.38461538e+01,8.00000000e+01 ,6.00000000e+01 ,8.00000000e+01, 1.30000000e+02,1.40000000e+02, 3.40000000e+02, 6.40000000e+02, 2.72000000e+03,6.93333333e+02, 9.20000000e+02, 1.30000000e+02, 4.50000000e+01,1.60000000e+01, 8.00000000e+00, 8.00000000e+00, 1.00000000e+01,6.00000000e+00, 1.00000000e+01, 3.63636364e+00, 1.11111111e+01,2.00000000e+00, 5.45454545e+00, 1.11111111e+01, 1.00000000e+01,7.69230769e+00 ,2.29166667e+01, 1.00000000e+01, 1.40000000e+01,2.77777778e+01, 5.21739130e+01, 4.00000000e+01, 1.60000000e+02,1.60000000e+02, 1.69230769e+02, 6.14285714e+02 ,8.80000000e+02,5.60000000e+02 ,1.80000000e+02, 1.70000000e+02])


plt.plot(V,dudv, 'b')




# plt.plot(V, U, 'b')
 
plt.xlabel('V in mL')

plt.ylabel('U in mV')

import matplotlib.pyplot as plt
import numpy as np
# max_dudv = max(dudv)  # Find the maximum y value
# max_V1 = V[dudv.argmax()]  # Find the x value corresponding to the maximum y value
 
# print(max_V1, max_dudv)
# plt.scatter(10.075, 2720.0)

# plt.annotate("   (10.075, 2720.0)", (10.075, 2720.0) )


print(dudv)

plt.show()
# Out:
# [3.00000000e+00 2.00000000e+00 4.00000000e+00 4.00000000e+00
#  4.00000000e+00 4.00000000e+00 6.00000000e+00 3.63636364e+00
#  6.66666667e+00 4.00000000e+00 6.00000000e+00 6.15384615e+00
#  1.14285714e+01 8.00000000e+00 1.20000000e+01 1.60000000e+01
#  2.00000000e+01 2.22222222e+01 4.00000000e+01 5.38461538e+01
#  8.00000000e+01 6.00000000e+01 8.00000000e+01 1.30000000e+02
#  1.40000000e+02 3.40000000e+02 6.40000000e+02 2.72000000e+03
#  6.93333333e+02 9.20000000e+02 1.30000000e+02 4.50000000e+01
#  1.60000000e+01 8.00000000e+00 8.00000000e+00 1.00000000e+01
#  6.00000000e+00 1.00000000e+01 3.63636364e+00 1.11111111e+01
#  2.00000000e+00 5.45454545e+00 1.11111111e+01 1.00000000e+01
#  7.69230769e+00 2.29166667e+01 1.00000000e+01 1.40000000e+01
#  2.77777778e+01 5.21739130e+01 4.00000000e+01 1.60000000e+02
#  1.60000000e+02 1.69230769e+02 6.14285714e+02 8.80000000e+02
#  5.60000000e+02 1.80000000e+02 1.70000000e+02]

# %%
from matplotlib import pyplot as plt

V = np.array([ 0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6,6.5,7,7.55,8,8.48,9,9.5,10.05,10.075,10.10,10.15,10.25,10.50,11,11.5,12.0,12.5,13,13.5,14.0,14.5,15.,15.5,16,16.5,17.0,17.55,18,18.5,19.0,19.5,19.58,19.61,19.70,19.85,19.90,19.98,20.25,20.50])
U = np.array([-3,-2,1,3,4,7,10,13,15,18,20,23,26,30,33,38,43,50,60,75,134,159,231,315,345,356,365,371,375,378,381,384,387,392,395,400,403,407,412,418,423,434,445,468,474,478,491,510,576,594,623,635])
# dUdV = np.diff(U) / np.diff(V)



from matplotlib import pyplot as plt


# fig = plt.figure()
# ax = fig.add_subplot(111)



# ax.plot(V,dudv)
# for xy in zip(V, dudv):                                       # <--
#     ax.annotate('(%s, %s)' % xy, xy=xy, textcoords='data') # <--

plt.xlabel('V in mL')


plt.ylabel('dU/dV')

 
plt.title('2. Vorgang')



dudv = np.array([2.00000000e+00, 6.00000000e+00 ,4.00000000e+00, 2.00000000e+00,6.00000000e+00 ,6.00000000e+00, 6.00000000e+00, 4.00000000e+00,6.00000000e+00, 4.00000000e+00, 6.00000000e+00, 6.00000000e+00,8.00000000e+00, 6.00000000e+00, 9.09090909e+00 ,1.11111111e+01,1.45833333e+01 ,1.92307692e+01, 3.00000000e+01, 1.07272727e+02,1.00000000e+03, 2.88000000e+03, 1.68000000e+03 ,3.00000000e+02,4.40000000e+01, 1.80000000e+01, 1.20000000e+01, 8.00000000e+00,6.00000000e+00, 6.00000000e+00, 6.00000000e+00 ,6.00000000e+00,1.00000000e+01, 6.00000000e+00, 1.00000000e+01 ,6.00000000e+00,8.00000000e+00, 1.00000000e+01, 1.09090909e+01 ,1.11111111e+01,2.20000000e+01 ,2.20000000e+01, 4.60000000e+01, 7.50000000e+01,1.33333333e+02, 1.44444444e+02, 1.26666667e+02, 1.32000000e+03,2.25000000e+02, 1.07407407e+02, 4.80000000e+01])

plt.plot(V,dudv, 'b')
#


# plt.plot(V, U, 'b')
plt.xlim(0, 21)

# print(len(V))
# print(len(dudv))
# Out:
# (0.0, 21.0)

# %%
from matplotlib import pyplot as plt

V = np.array([0.5,1,1.5,2,2.5,3,3.5,4.05,4.55,5,5.5,6.05,6.5,7,7.5,8,8.5,9,9.5,9.95,10.07,10.10,10.17,10.30,11,11.5,12.0,12.5,13,13.5,14.0,14.5,15.,15.57,16,16.5,17.0,17.5,18,18.5,19.0,19.5,19.60,19.65,19.75,19.80,19.85,19.95,20.])
U = np.array([3,5,6,8,10,12,15,17,19,21,23,26,29,32,36,41,47,55,65,81,129,286,302,333,357,365,371,378,381,384,388,391,394,397,402,405,411,416,421,427,437,451,472,484,498,528,569,583,601,605])
# dUdV = np.diff(U) / np.diff(V)



# fig = plt.figure()
# ax = fig.add_subplot(111)



# ax.plot(V,dudv)
# for xy in zip(V, dudv):                                       # <--
#     ax.annotate('(%s, %s)' % xy, xy=xy, textcoords='data') # <--

plt.xlabel('V in mL')

plt.ylabel('dU/dV')

 
plt.title('3. Vorgang')



dudv = np.array([ 4.    ,        2.          ,  4.   ,         4.    ,        4.,6.   ,         4.   ,         3.63636364 ,   4.  ,          4.44444444,6.    ,        5.45454545  ,  6.66666667 ,   8.   ,        10.,12.     ,      16.     ,      20.   ,        32.,          106.66666667,1308.33333333  ,533.33333333 , 442.85714286 , 184.61538462 ,  11.42857143,  12.      ,     14.   ,         6.    ,        6.  ,          8.,  6.   ,         6.   ,         6.  ,          8.77192982 ,   6.97674419, 12.   ,        10.   ,        10. ,          12. ,          20., 28.   ,        42.    ,      120. ,         280.  ,        300.,820.    ,      280.    ,      180.  ,         80.    ])
plt.plot(V,dudv,'b')



# plt.plot(V, U, '')

print(len(V))
print(len(dudv))
# Out:
# 49
# 49
